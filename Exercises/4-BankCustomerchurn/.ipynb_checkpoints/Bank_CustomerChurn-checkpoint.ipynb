# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np

# %%
# %ls
# Out:
# Bank_CustomerChurn.ipynb  Churn_Modelling.csv

# %%
df = pd.read_csv('Churn_Modelling.csv')
df
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0          2       0.00              1          1               1
# 1          1   83807.86              1          0               1
# 2          8  159660.80              3          1               0
# 3          1       0.00              2          0               0
# 4          2  125510.82              1          1               1
# ...      ...        ...            ...        ...             ...
# 9995       5       0.00              2          1               0
# 9996      10   57369.61              1          1               1
# 9997       7       0.00              1          0               1
# 9998       3   75075.31              2          1               0
# 9999       4  130142.79              1          1               0
#
#       EstimatedSalary  Exited
# 0           101348.88       1
# 1           112542.58       0
# 2           113931.57       1
# 3            93826.63       0
# 4            79084.10       0
# ...               ...     ...
# 9995         96270.64       0
# 9996        101699.77       0
# 9997         42085.58       1
# 9998         92888.52       1
# 9999         38190.78       0
#
# [10000 rows x 14 columns]

# %%
df1 = df.drop(['RowNumber','CustomerId','Surname'],axis='columns')
df1
# Out:
#       CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0             619    France  Female   42       2       0.00              1
# 1             608     Spain  Female   41       1   83807.86              1
# 2             502    France  Female   42       8  159660.80              3
# 3             699    France  Female   39       1       0.00              2
# 4             850     Spain  Female   43       2  125510.82              1
# ...           ...       ...     ...  ...     ...        ...            ...
# 9995          771    France    Male   39       5       0.00              2
# 9996          516    France    Male   35      10   57369.61              1
# 9997          709    France  Female   36       7       0.00              1
# 9998          772   Germany    Male   42       3   75075.31              2
# 9999          792    France  Female   28       4  130142.79              1
#
#       HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0             1               1        101348.88       1
# 1             0               1        112542.58       0
# 2             1               0        113931.57       1
# 3             0               0         93826.63       0
# 4             1               1         79084.10       0
# ...         ...             ...              ...     ...
# 9995          1               0         96270.64       0
# 9996          1               1        101699.77       0
# 9997          0               1         42085.58       1
# 9998          1               0         92888.52       1
# 9999          1               0         38190.78       0
#
# [10000 rows x 11 columns]

# %%
df1['Geography'].unique()
# Out:
# array(['France', 'Spain', 'Germany'], dtype=object)

# %%
df1['Balance']=df1['Balance']/(df1['Balance'].median())
df1['EstimatedSalary']=df1['EstimatedSalary']/(df1['EstimatedSalary'].median())
df1['Age']=df1['Age']/(df1['Age'].median())
df1['CreditScore']=df1['CreditScore']/(df1['CreditScore'].median())
#df1['Tenure']=df1['Tenure']/(df1['Tenure'].median())

# %%
l = []
for val in df1['Geography']:
    if val == 'France':
        l.append(0)
    elif val == 'Spain':
        l.append(1)
    else:
        l.append(2)
df1['Geography']=l
l = []
for val in df1['Gender']:
    if val == 'Female':
        l.append(0)
    else:
        l.append(1)
df1['Gender']=l

# %%
X = df1.drop(['Exited'],axis='columns')
y = df1['Exited']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.25)

# %%
len(X_train),len(X_test),len(y_train),len(y_test)
# Out:
# (7500, 2500, 7500, 2500)

# %%
import tensorflow as tf
from tensorflow import keras
X_train.shape
# Out:
# (7500, 10)

# %%
model = keras.Sequential([
    keras.layers.Dense(100,input_shape=(10,),activation='relu'),
    keras.layers.Dense(10,activation='relu'),
    keras.layers.Dense(10,activation='relu'),
    keras.layers.Dense(2,activation='softmax')
])
model.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])
model

# %%
model.fit(X_train,y_train,epochs=30)
# Out:
# Epoch 1/30
# 235/235 [==============================] - 0s 807us/step - loss: 0.5440 - accuracy: 0.7584
# Epoch 2/30
# 235/235 [==============================] - 0s 789us/step - loss: 0.4472 - accuracy: 0.7948
# Epoch 3/30
# 235/235 [==============================] - 0s 786us/step - loss: 0.4081 - accuracy: 0.8221
# Epoch 4/30
# 235/235 [==============================] - 0s 801us/step - loss: 0.3877 - accuracy: 0.8313
# Epoch 5/30
# 235/235 [==============================] - 0s 806us/step - loss: 0.3805 - accuracy: 0.8373
# Epoch 6/30
# 235/235 [==============================] - 0s 805us/step - loss: 0.3752 - accuracy: 0.8405
# Epoch 7/30
# 235/235 [==============================] - 0s 790us/step - loss: 0.3696 - accuracy: 0.8496
# Epoch 8/30
# 235/235 [==============================] - 0s 773us/step - loss: 0.3696 - accuracy: 0.8460
# Epoch 9/30
# 235/235 [==============================] - 0s 779us/step - loss: 0.3669 - accuracy: 0.8485
